# %%
import pandas as pd
import numpy as np
from entity_recognition import get_locations

# %%
df = pd.read_csv('search-result-2022-11-08-04-04-19(1).csv')
df = df[['Type', 'Label', 'Headline', 'Body', 'Byline', 'Publish Date']]

df.head()
# Out:
#       Type                                              Label  \
# 0  Article  Watertown Police Detective Alleges Hostile Wor...
# 1  Article  In 2020, Larissa FastHorse's 'The Thanksgiving...
# 2  Article  In From The Cold: Martha’s Vineyard To Open It...
# 3  Article  Retail Behemoth Amazon May Be Coming To The Si...
# 4  Article   Rollins Talking Criminal Justice With Biden Team
#
#                                             Headline  \
# 0  Watertown Police Detective Alleges Hostile Wor...
# 1  In 2020, Larissa FastHorse's 'The Thanksgiving...
# 2  In From The Cold: Martha’s Vineyard To Open It...
# 3  Retail Behemoth Amazon May Be Coming To The Si...
# 4   Rollins Talking Criminal Justice With Biden Team
#
#                                                 Body  \
# 0  BOSTON (AP) — A Watertown police detective all...
# 1  In late October, Native American playwright <a...
# 2  For the past five winters, three Martha’s Vine...
# 3  A site plan filed with the city of Worcester’s...
# 4  While she said &quot;right now I&#39;m stickin...
#
#                                          Byline                  Publish Date
# 0                              Associated Press  Wed Nov 18 14:39:02 EST 2020
# 1                                  Jill Kaufman  Fri Nov 20 16:34:53 EST 2020
# 2                               Jennette Barnes  Tue Nov 24 15:48:23 EST 2020
# 3                               Aaron Schachter  Fri Nov 27 15:11:17 EST 2020
# 4  Michael P. Norton | State House News Service  Mon Nov 30 08:49:08 EST 2020

# %%
df['combined_text'] = df.Label + df.Headline + df.Body
df['locations'] = df.apply(lambda row: get_locations(row.combined_text), axis = 1)

df.head()
# Out:
#       Type                                              Label  \
# 0  Article  Watertown Police Detective Alleges Hostile Wor...
# 1  Article  In 2020, Larissa FastHorse's 'The Thanksgiving...
# 2  Article  In From The Cold: Martha’s Vineyard To Open It...
# 3  Article  Retail Behemoth Amazon May Be Coming To The Si...
# 4  Article   Rollins Talking Criminal Justice With Biden Team
#
#                                             Headline  \
# 0  Watertown Police Detective Alleges Hostile Wor...
# 1  In 2020, Larissa FastHorse's 'The Thanksgiving...
# 2  In From The Cold: Martha’s Vineyard To Open It...
# 3  Retail Behemoth Amazon May Be Coming To The Si...
# 4   Rollins Talking Criminal Justice With Biden Team
#
#                                                 Body  \
# 0  BOSTON (AP) — A Watertown police detective all...
# 1  In late October, Native American playwright <a...
# 2  For the past five winters, three Martha’s Vine...
# 3  A site plan filed with the city of Worcester’s...
# 4  While she said &quot;right now I&#39;m stickin...
#
#                                          Byline                  Publish Date  \
# 0                              Associated Press  Wed Nov 18 14:39:02 EST 2020
# 1                                  Jill Kaufman  Fri Nov 20 16:34:53 EST 2020
# 2                               Jennette Barnes  Tue Nov 24 15:48:23 EST 2020
# 3                               Aaron Schachter  Fri Nov 27 15:11:17 EST 2020
# 4  Michael P. Norton | State House News Service  Mon Nov 30 08:49:08 EST 2020
#
#                                        combined_text  \
# 0  Watertown Police Detective Alleges Hostile Wor...
# 1  In 2020, Larissa FastHorse's 'The Thanksgiving...
# 2  In From The Cold: Martha’s Vineyard To Open It...
# 3  Retail Behemoth Amazon May Be Coming To The Si...
# 4  Rollins Talking Criminal Justice With Biden Te...
#
#                                            locations
# 0                 {(Watertown, GPE), (Louison, GPE)}
# 1  {(Vermont, GPE), (New Jersey, GPE), (Lenox, GP...
# 2  {(Oak Bluffs, GPE), (homelessness.<br/><br/>Th...
# 3  {(site.<br/><br/>“Though, GPE), (Boston, GPE),...
# 4  {(Boston, GPE), (Washington, GPE), (Suffolk Co...

# %%
df.to_csv('data_with_locations.csv')

# %%
#df = pd.read_csv('data_with_locations.csv')

# %%
def extract_locations(locations : pd.Series) -> pd.DataFrame:
    df = pd.DataFrame(columns = ['location', 'count'])
    
    for loc in locations:
        for val in loc:
            if val[0].lower() not in df['location'].values:
                new = {'location': val[0].lower(), 'count': 1}
                df = df.append(new, ignore_index = True)
            else:
                idx = df.index[df['location'] == val[0].lower()]
                df['count'].iloc[idx] += 1
    
    return df

# %%
import warnings
warnings.filterwarnings("ignore")

loc_df = extract_locations(df['locations'])

loc_df.head()
# Out:
#      location count
# 0   watertown     4
# 1     louison     1
# 2     vermont     7
# 3  new jersey     8
# 4       lenox     1

# %%
invalid_chars = ['.', '/', '>', '<', '!', '?', '#', ';', ':', '1', '2', '3', '4', '5', '6', '7', '8' \
                 '9', '0', '(', ')']
idxs = []

for i in range(len(loc_df)):
    loc = loc_df['location'].iloc[i]
    for c in invalid_chars:
        if c in loc:
            idxs.append(i)
            
loc_df = loc_df.drop(labels=idxs, axis=0).reset_index(drop=True)
loc_df = loc_df.sort_values('count', ascending = False)

loc_df
# Out:
#                 location count
# 0          massachusetts   184
# 1                 boston   119
# 2      the united states    45
# 3               new york    32
# 4              cambridge    28
# ..                   ...   ...
# 283              duxbury     1
# 282               greece     1
# 281            nicaragua     1
# 280  san francisco state     1
# 507           witch city     1
#
# [508 rows x 2 columns]

# %%
temp_loc_df = loc_df[(loc_df['location'] != 'massachusetts') & (loc_df['location'] != 'boston') & \
                     (loc_df['location'] != 'the united states') & (loc_df['location'] != 'new york') & \
                     (loc_df['location'] != 'america') & (loc_df['location'] != 'us')]

# %%
temp_loc_df[:30].plot.bar(x = 'location', y = 'count')
# Out:
# <AxesSubplot:xlabel='location'>
